# %%
import math
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
import cv2
import itertools
images_all = np.array(np.load('Images_32 (1).npy'))/255
labels_all= np.load('Labels_32.npy')

# %%
print(labels_all)
print(len(labels_all))
# Out:
# [0 0 0 ... 3 3 3]
# 11383

# %%
print(np.min(images_all[37]))
print(np.max(images_all[37]))
plt.imshow(images_all[37])
print(np.shape(images_all[37]))
# Out:
# 0.0
# 1.0
# (200, 200, 3)

# %%
    set1_d=[]
    set2_d=[]
    set3_d=[]
    set4_d=[]
    set5_d=[]
    
    set1_l=[]
    set2_l=[]
    set3_l=[]
    set4_l=[]
    set5_l=[]

    r=len(labels_all)
    #print(r)
    for i in range(r):

        if i%5==0: 
            set1_d+=[images_all[i,:]]
            set1_l+=[labels_all[i]]
        elif  i%5==1: 
            set2_d+=[images_all[i,:]]
            set2_l+=[labels_all[i]]
        elif  i%5==2: #
            set3_d+=[images_all[i,:]]
            set3_l+=[labels_all[i]]
        elif  i%5==3: 
            set4_d+=[images_all[i,:]]
            set4_l+=[labels_all[i]]
        else:
            set5_d+=[images_all[i,:]]
            set5_l+=[labels_all[i]]


np.save('set1_d', set1_d)
np.save('set1_l', set1_l)

np.save('set2_d', set2_d)
np.save('set2_l', set2_l)

np.save('set3_d', set3_d)
np.save('set3_l', set3_l)

np.save('set4_d', set4_d)
np.save('set4_l', set4_l)

# %%
print(len(set1_l), len(set2_l), len(set3_l), len(set4_l), len(set5_l))
# Out:
# 2277 2277 2277 2276 2276

# %%
plt.imshow(set1_d[3])
print(np.shape(set1_d[37]))
# Out:
# (200, 200, 3)
